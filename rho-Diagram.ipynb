# %%
include("euler-1d.jl")

using Plots

rho_out = [elem[1] for elem in U][3:end-2]
x_out = [0.5*(x[i] + x[i+1]) for i=1:N]

p1 = plot(x_out, rho_out)
p2 = plot(x, rho_ex)
plot(p1, p2)
# Out:
# fsLA: simple laser hydrodynamic code v0.1, (c) Vadim V. Shepelev, Ph.D.
#
# size(x) = (101,)
# size(U) = (104,)
#
# Starting simulation...
# iter=1 t=0 dt=0.000931 CFL=0.9
# iter=2 t=0.000931 dt=0.000929 CFL=0.9
# iter=3 t=0.00186 dt=0.000856 CFL=0.9
# iter=4 t=0.00272 dt=0.000812 CFL=0.9
# iter=5 t=0.00353 dt=0.000789 CFL=0.9
# iter=6 t=0.00432 dt=0.00388 CFL=0.9
# iter=7 t=0.0082 dt=0.00372 CFL=0.9
# iter=8 t=0.0119 dt=0.00358 CFL=0.9
# iter=9 t=0.0155 dt=0.00354 CFL=0.9
# iter=10 t=0.019 dt=0.00355 CFL=0.9
# iter=11 t=0.0226 dt=0.00349 CFL=0.9
# iter=12 t=0.0261 dt=0.00345 CFL=0.9
# iter=13 t=0.0295 dt=0.00344 CFL=0.9
# iter=14 t=0.033 dt=0.00342 CFL=0.9
# iter=15 t=0.0364 dt=0.00339 CFL=0.9
# iter=16 t=0.0398 dt=0.00338 CFL=0.9
# iter=17 t=0.0432 dt=0.00337 CFL=0.9
# iter=18 t=0.0465 dt=0.00335 CFL=0.9
# iter=19 t=0.0499 dt=0.00335 CFL=0.9
# iter=20 t=0.0532 dt=0.00334 CFL=0.9
# iter=21 t=0.0566 dt=0.00333 CFL=0.9
# iter=22 t=0.0599 dt=0.00333 CFL=0.9
# ...

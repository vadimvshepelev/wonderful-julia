# %%
include("euler-1d.jl")

using Plots

rho_out = [elem[1] for elem in U][3:end-2]
x_out = [0.5*(x[i] + x[i+1]) for i=1:N]

p1 = plot(x_out, rho_out)
p2 = plot(x, rho_ex)
plot(p1, p2)
# Out:
# fsLA: simple laser hydrodynamic code v0.1, (c) Vadim V. Shepelev, Ph.D.
#
# size(x) = (101,)
# size(U) = (104,)
#
# Starting simulation...
# iter 1 dt=0.00760638829255665 t=0.0
# iter 2 dt=0.00760638829255665 t=0.00760638829255665
# Exact solution:
